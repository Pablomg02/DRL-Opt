# %%
import gymnasium as gym

from stable_baselines3 import DQN, PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Create environment
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("pendulo")
del model  # delete trained model to demonstrate loading
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 22.2     |
# | time/              |          |
# |    fps             | 3710     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.7        |
# |    ep_rew_mean          | 28.7        |
# | time/                   |             |
# |    fps                  | 2374        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008533258 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00715    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.91        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 52.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34          |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 2124        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008740924 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0799      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 44.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.6        |
# |    ep_rew_mean          | 41.6        |
# | time/                   |             |
# |    fps                  | 2017        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008381795 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.9        |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 1955        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009170068 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 61          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74.4       |
# |    ep_rew_mean          | 74.4       |
# | time/                   |            |
# |    fps                  | 1922       |
# |    iterations           | 6          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00833667 |
# |    clip_fraction        | 0.0555     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.602     |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20.3       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0136    |
# |    value_loss           | 64.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.5        |
# |    ep_rew_mean          | 89.5        |
# | time/                   |             |
# |    fps                  | 1905        |
# |    iterations           | 7           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011621668 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 62.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 108         |
# | time/                   |             |
# |    fps                  | 1886        |
# |    iterations           | 8           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009744983 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 56.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 1865        |
# |    iterations           | 9           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003287657 |
# |    clip_fraction        | 0.0291      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 56.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 146        |
# |    ep_rew_mean          | 146        |
# | time/                   |            |
# |    fps                  | 1856       |
# |    iterations           | 10         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01021626 |
# |    clip_fraction        | 0.0657     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.553     |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.04       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00495   |
# |    value_loss           | 23.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 1852         |
# |    iterations           | 11           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0067893886 |
# |    clip_fraction        | 0.0855       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 28.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | 182         |
# | time/                   |             |
# |    fps                  | 1846        |
# |    iterations           | 12          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008268455 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.007      |
# |    value_loss           | 78.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 1842        |
# |    iterations           | 13          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009516824 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | -0.39       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.238       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 5.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 219         |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 1839        |
# |    iterations           | 14          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010554205 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | 236        |
# | time/                   |            |
# |    fps                  | 1836       |
# |    iterations           | 15         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00444876 |
# |    clip_fraction        | 0.0378     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.53      |
# |    explained_variance   | 0.00359    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.1       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00563   |
# |    value_loss           | 25.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 254          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 1834         |
# |    iterations           | 16           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053762533 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | -0.478       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0396       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 1.69         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 1832        |
# |    iterations           | 17          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008789184 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | -0.0304     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0135      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 0.923       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 289          |
# |    ep_rew_mean          | 289          |
# | time/                   |              |
# |    fps                  | 1828         |
# |    iterations           | 18           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0072506852 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | 0.396        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0297       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0047      |
# |    value_loss           | 0.586        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 307          |
# | time/                   |              |
# |    fps                  | 1824         |
# |    iterations           | 19           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0039315047 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00312     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 0.388        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 324          |
# | time/                   |              |
# |    fps                  | 1822         |
# |    iterations           | 20           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0062676305 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | -0.0188      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0196       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 0.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 344          |
# | time/                   |              |
# |    fps                  | 1821         |
# |    iterations           | 21           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0054925717 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00783      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 0.143        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 358          |
# |    ep_rew_mean          | 358          |
# | time/                   |              |
# |    fps                  | 1819         |
# |    iterations           | 22           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0052280566 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.07         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0207       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 0.0925       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | 374          |
# | time/                   |              |
# |    fps                  | 1818         |
# |    iterations           | 23           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0017365158 |
# |    clip_fraction        | 0.00542      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00835     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000575    |
# |    value_loss           | 0.0569       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 389          |
# |    ep_rew_mean          | 389          |
# | time/                   |              |
# |    fps                  | 1816         |
# |    iterations           | 24           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0032220923 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0153      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000962    |
# |    value_loss           | 0.0339       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 403          |
# |    ep_rew_mean          | 403          |
# | time/                   |              |
# |    fps                  | 1815         |
# |    iterations           | 25           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0054463977 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0186      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00501     |
# |    value_loss           | 0.0214       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 415          |
# |    ep_rew_mean          | 415          |
# | time/                   |              |
# |    fps                  | 1814         |
# |    iterations           | 26           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0059510753 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0113       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 0.014        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 428          |
# |    ep_rew_mean          | 428          |
# | time/                   |              |
# |    fps                  | 1814         |
# |    iterations           | 27           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0028144545 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.0141       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00407     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 0.0089       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 440         |
# |    ep_rew_mean          | 440         |
# | time/                   |             |
# |    fps                  | 1813        |
# |    iterations           | 28          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004259898 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.442      |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0249     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 0.00579     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 454         |
# |    ep_rew_mean          | 454         |
# | time/                   |             |
# |    fps                  | 1813        |
# |    iterations           | 29          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004870076 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 0.00387     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 463         |
# |    ep_rew_mean          | 463         |
# | time/                   |             |
# |    fps                  | 1811        |
# |    iterations           | 30          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.002924561 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.426      |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00508    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 0.00267     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 470         |
# |    ep_rew_mean          | 470         |
# | time/                   |             |
# |    fps                  | 1809        |
# |    iterations           | 31          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.002903283 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.0177      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0029     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 0.00174     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 477         |
# | time/                   |             |
# |    fps                  | 1808        |
# |    iterations           | 32          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003359287 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.419      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0353      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 0.00123     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 482          |
# |    ep_rew_mean          | 482          |
# | time/                   |              |
# |    fps                  | 1808         |
# |    iterations           | 33           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0029133135 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.406       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00899     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000978    |
# |    value_loss           | 0.000872     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | 489         |
# | time/                   |             |
# |    fps                  | 1808        |
# |    iterations           | 34          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.002197085 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | -0.104      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00269     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 0.000568    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 497          |
# |    ep_rew_mean          | 497          |
# | time/                   |              |
# |    fps                  | 1784         |
# |    iterations           | 35           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0038909127 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | -0.14        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0156      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00037     |
# |    value_loss           | 0.000388     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | 497         |
# | time/                   |             |
# |    fps                  | 1726        |
# |    iterations           | 36          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.002738216 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00951    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 0.000266    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 497          |
# |    ep_rew_mean          | 497          |
# | time/                   |              |
# |    fps                  | 1668         |
# |    iterations           | 37           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0019248072 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.403       |
# |    explained_variance   | -0.0456      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00233      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000874    |
# |    value_loss           | 0.00021      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1614         |
# |    iterations           | 38           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0014510616 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.396       |
# |    explained_variance   | -0.117       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00171     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000624    |
# |    value_loss           | 0.000143     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1564        |
# |    iterations           | 39          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005458232 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | -0.148      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00421    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 0.000105    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1534        |
# |    iterations           | 40          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004166255 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.39       |
# |    explained_variance   | -0.328      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0262      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 6.99e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1484        |
# |    iterations           | 42          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008326848 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 3.4e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1454        |
# |    iterations           | 43          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005104665 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.411      |
# |    explained_variance   | -0.159      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00763    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 3.02e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1436        |
# |    iterations           | 44          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005718845 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | -0.467      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 2.32e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1428         |
# |    iterations           | 45           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0065846285 |
# |    clip_fraction        | 0.0887       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.409       |
# |    explained_variance   | -0.249       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000493    |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00507     |
# |    value_loss           | 1.6e-05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1435         |
# |    iterations           | 46           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0012942518 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.408       |
# |    explained_variance   | -0.616       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00199     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000945    |
# |    value_loss           | 1.25e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 47          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004004496 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | -0.538      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00734    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 8.71e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1447         |
# |    iterations           | 48           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0051856074 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.392       |
# |    explained_variance   | -0.734       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00594     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 7.51e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1452         |
# |    iterations           | 49           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0037529538 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | -0.647       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00419     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 4.83e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1463        |
# |    iterations           | 51          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.004344713 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.336      |
# |    explained_variance   | -0.392      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00103    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 3.82e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1468         |
# |    iterations           | 52           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0041921367 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.31        |
# |    explained_variance   | -0.432       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00212     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 2.49e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1472         |
# |    iterations           | 53           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0010634251 |
# |    clip_fraction        | 0.00752      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | -0.378       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000964    |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000386    |
# |    value_loss           | 2.03e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1477        |
# |    iterations           | 54          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.003380697 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.301      |
# |    explained_variance   | -0.892      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00221    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 1.71e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1482         |
# |    iterations           | 55           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0009123151 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.294       |
# |    explained_variance   | -0.68        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00662     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000757    |
# |    value_loss           | 2.05e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1486         |
# |    iterations           | 56           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0011361425 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.29        |
# |    explained_variance   | -0.187       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00313     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000153    |
# |    value_loss           | 1.24e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1491         |
# |    iterations           | 57           |
# |    time_elapsed         | 78           |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0037416418 |
# |    clip_fraction        | 0.0413       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000932     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 3.4e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1569         |
# |    iterations           | 82           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0015000594 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -0.289       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0022       |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 2.99e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1571        |
# |    iterations           | 83          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.004362763 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | -1.48       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0112     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.000499   |
# |    value_loss           | 3.87e-07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | 500           |
# | time/                   |               |
# |    fps                  | 1574          |
# |    iterations           | 84            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00060050667 |
# |    clip_fraction        | 0.00937       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.243        |
# |    explained_variance   | -0.0736       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00296       |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -3.18e-05     |
# |    value_loss           | 3.26e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 500           |
# |    ep_rew_mean          | 500           |
# | time/                   |               |
# |    fps                  | 1576          |
# |    iterations           | 85            |
# |    time_elapsed         | 110           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.00085692084 |
# |    clip_fraction        | 0.00718       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.26         |
# |    explained_variance   | 0.0338        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00441      |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -1.49e-05     |
# |    value_loss           | 5.21e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1578         |
# |    iterations           | 86           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0029689968 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | -0.00316     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00199      |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.000552    |
# |    value_loss           | 1.53e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1580         |
# |    iterations           | 87           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0012260629 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | -0.334       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00698      |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.000368    |
# |    value_loss           | 2.58e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1582         |
# |    iterations           | 88           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0017327332 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | -0.868       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00808      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -1.45e-06    |
# |    value_loss           | 1.76e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1583         |
# |    iterations           | 89           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0035957703 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.237       |
# |    explained_variance   | -0.214       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00744     |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 3.31e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1585         |
# |    iterations           | 90           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0036534057 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -0.291       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00137     |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 2.68e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1586         |
# |    iterations           | 91           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0034698106 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | -0.126       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00164      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 5.23e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1588        |
# |    iterations           | 92          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.003382532 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.262      |
# |    explained_variance   | -1.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -7.13e-05   |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 3.47e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 1590        |
# |    iterations           | 93          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.002223761 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.247      |
# |    explained_variance   | -0.3        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00228    |
# |    value_loss           | 7.5e-06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1592         |
# |    iterations           | 94           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0017466708 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | -1.95        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0124      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000717    |
# |    value_loss           | 2.62e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 95           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0011146434 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -0.409       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00391     |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 9.38e-05     |
# |    value_loss           | 3.21e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1595         |
# |    iterations           | 96           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0011133893 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.00458      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00425      |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -4.29e-05    |
# |    value_loss           | 6.2e-05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1596         |
# |    iterations           | 97           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0016089084 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | -0.0586      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00368      |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.000424    |
# |    value_loss           | 2.84e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 1598         |
# |    iterations           | 98           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0036791188 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | -2.85        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00217     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -9.38e-05    |
# |    value_loss           | 1.25e-07     |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
model = PPO.load("pendulo", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
